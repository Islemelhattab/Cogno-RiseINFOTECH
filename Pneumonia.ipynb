# %%
from google.colab import drive

# Use drive.mount with authentication
drive.mount('/content/Drive', force_remount=True)

# %%
cd /content/Drive/MyDrive/Colab Notebooks
# Out:
# /content/Drive/MyDrive/Colab Notebooks

# %%
pwd
# Out:
# '/content/Drive/MyDrive/Colab Notebooks'

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-dcd934fa-b198-4c03-9312-934348078d60" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dcd934fa-b198-4c03-9312-934348078d60">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle

# %%
# !mkdir -p ~/.kaggle

# %%
# !cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d amanullahasraf/covid19-pneumonia-normal-chest-xray-pa-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/amanullahasraf/covid19-pneumonia-normal-chest-xray-pa-dataset
# License(s): CC0-1.0
# ...
# 100% 1.91G/1.91G [00:29<00:00, 91.0MB/s]
# 100% 1.91G/1.91G [00:29<00:00, 70.4MB/s]

# %%
! unzip covid19-pneumonia-normal-chest-xray-pa-dataset.zip
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: covid/COVID19(303).jpg
#   inflating: covid/COVID19(304).jpg
#   inflating: covid/COVID19(305).jpg
#   inflating: covid/COVID19(306).jpg
#   inflating: covid/COVID19(307).jpg
#   inflating: covid/COVID19(308).jpg
#   inflating: covid/COVID19(309).jpg
#   inflating: covid/COVID19(31).jpg
#   inflating: covid/COVID19(310).jpg
#   inflating: covid/COVID19(311).jpg
#   inflating: covid/COVID19(312).jpg
#   inflating: covid/COVID19(313).jpg
#   inflating: covid/COVID19(314).jpg
#   inflating: covid/COVID19(315).jpg
#   inflating: covid/COVID19(316).jpg
#   inflating: covid/COVID19(317).jpg
#   inflating: covid/COVID19(318).jpg
#   inflating: covid/COVID19(319).jpg
#   inflating: covid/COVID19(32).jpg
#   inflating: covid/COVID19(320).jpg
#   inflating: covid/COVID19(321).jpg
#   inflating: covid/COVID19(322).jpg
#   inflating: covid/COVID19(323).jpg
#   inflating: covid/COVID19(324).jpg
# ...

# %%
import os
import random
import shutil

# %% [markdown]
# # **Splitting the dataset into training, testing and validation**

# %%
#split

data_path = "3IDL_DataSet/normal"

# path to destination folders
train_folder = os.path.join("3IDLDataSet/", 'train/normal')
val_folder = os.path.join("3IDLDataSet/", 'val/normal')
test_folder = os.path.join("3IDLDataSet/", 'test/normal')

# Define a list of image extensions
image_extensions = ['.png']

# Create a list of image filenames in 'data_path'
imgs_list = [filename for filename in os.listdir(data_path) if os.path.splitext(filename)[-1] in image_extensions]

# Sets the random seed
random.seed(42)

# Shuffle the list of image filenames
random.shuffle(imgs_list)

# determine the number of images for each set
train_size = int(len(imgs_list) * 0.7)
val_size = int(len(imgs_list) * 0.10)
test_size = int(len(imgs_list) * 0.20)

# Create destination folders if they don't exist
for folder_path in [train_folder, val_folder, test_folder]:
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Copy image files to destination folders
for i, f in enumerate(imgs_list):
    if i < train_size:
        dest_folder = train_folder
    elif i < train_size + val_size:
        dest_folder = val_folder
    else:
        dest_folder = test_folder
    shutil.copy(os.path.join(data_path, f), os.path.join(dest_folder, f))

# %%
#split

data_path = "3IDL_DataSet/covid"

# path to destination folders
train_folder = os.path.join("3IDLDataSet/", 'train/covid')
val_folder = os.path.join("3IDLDataSet/", 'val/covid')
test_folder = os.path.join("3IDLDataSet/", 'test/covid')

# Define a list of image extensions
image_extensions = ['.png']

# Create a list of image filenames in 'data_path'
imgs_list = [filename for filename in os.listdir(data_path) if os.path.splitext(filename)[-1] in image_extensions]

# Sets the random seed
random.seed(42)

# Shuffle the list of image filenames
random.shuffle(imgs_list)

# determine the number of images for each set
train_size = int(len(imgs_list) * 0.7)
val_size = int(len(imgs_list) * 0.10)
test_size = int(len(imgs_list) * 0.20)

# Create destination folders if they don't exist
for folder_path in [train_folder, val_folder, test_folder]:
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Copy image files to destination folders
for i, f in enumerate(imgs_list):
    if i < train_size:
        dest_folder = train_folder
    elif i < train_size + val_size:
        dest_folder = val_folder
    else:
        dest_folder = test_folder
    shutil.copy(os.path.join(data_path, f), os.path.join(dest_folder, f))

# %%
#split

data_path = "3IDL_DataSet/pneumonia"

# path to destination folders
train_folder = os.path.join("3IDLDataSet/", 'train/pneumonia')
val_folder = os.path.join("3IDLDataSet/", 'val/pneumonia')
test_folder = os.path.join("3IDLDataSet/", 'test/pneumonia')

# Define a list of image extensions
image_extensions = ['.png']

# Create a list of image filenames in 'data_path'
imgs_list = [filename for filename in os.listdir(data_path) if os.path.splitext(filename)[-1] in image_extensions]

# Sets the random seed
random.seed(42)

# Shuffle the list of image filenames
random.shuffle(imgs_list)

# determine the number of images for each set
train_size = int(len(imgs_list) * 0.7)
val_size = int(len(imgs_list) * 0.10)
test_size = int(len(imgs_list) * 0.20)

# Create destination folders if they don't exist
for folder_path in [train_folder, val_folder, test_folder]:
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

# Copy image files to destination folders
for i, f in enumerate(imgs_list):
    if i < train_size:
        dest_folder = train_folder
    elif i < train_size + val_size:
        dest_folder = val_folder
    else:
        dest_folder = test_folder
    shutil.copy(os.path.join(data_path, f), os.path.join(dest_folder, f))

# %% [markdown]
# # **Defining the directories for later use**

# %%
#Defining the directories
train_normal_dir=os.path.join('3IDLDataSet/train/normal')
train_PNEUMONIA_dir=os.path.join('3IDLDataSet/train/pneumonia')
train_covid_dir=os.path.join('3IDLDataSet/train/covid')

test_normal_dir=os.path.join('3IDLDataSet/test/normal')
test_PNEUMONIA_dir=os.path.join('3IDLDataSet/test/pneumonia')
test_covid_dir=os.path.join('3IDLDataSet/test/covid')

val_normal_dir=os.path.join('3IDLDataSet/val/normal')
val_PNEUMONIA_dir=os.path.join('3IDLDataSet/val/pneumonia')
val_covid_dir=os.path.join('3IDLDataSet/val/covid')

#Printing the total numbers of data
print('Total Training Normal Xrays: ',len(os.listdir(train_normal_dir)))
print('Total Training PNEUMONIA Xrays: ',len(os.listdir(train_PNEUMONIA_dir)))
print('Total Training COVID Xrays: ',len(os.listdir(train_covid_dir)))

print('Total Test Normal Xrays: ',len(os.listdir(test_normal_dir)))
print('Total Test PNEUMONIA Xrays: ',len(os.listdir(test_PNEUMONIA_dir)))
print('Total Test COVID Xrays: ',len(os.listdir(test_covid_dir)))

print('Total Validation Normal Xrays: ',len(os.listdir(val_normal_dir)))
print('Total Validation PNEUMONIA Xrays: ',len(os.listdir(val_PNEUMONIA_dir)))
print('Total Validation COVID Xrays: ',len(os.listdir(val_covid_dir)))
# Out:
# Total Training Normal Xrays:  1383
# Total Training PNEUMONIA Xrays:  123
# Total Training COVID Xrays:  214
# Total Test Normal Xrays:  397
# Total Test PNEUMONIA Xrays:  36
# Total Test COVID Xrays:  62
# Total Validation Normal Xrays:  197
# Total Validation PNEUMONIA Xrays:  17
# Total Validation COVID Xrays:  30

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# # **Preprocessing Step**

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255)


train_generator=train_datagen.flow_from_directory(
      '/content/Drive/MyDrive/Colab Notebooks/3IDLDataSet/train', # Fixed the typo in the path. Changed 'drive' to 'Drive'
      target_size=(256, 256),
      batch_size=32,
      class_mode='categorical',
)

test_datagen=ImageDataGenerator(rescale=1./255)
test_generator=train_datagen.flow_from_directory(
      '/content/Drive/MyDrive/Colab Notebooks/3IDLDataSet/test', # Fixed the typo in the path. Changed 'drive' to 'Drive'
      target_size=(256, 256),
      batch_size=8,
      class_mode='categorical',
      shuffle=False
)

val_datagen=ImageDataGenerator(rescale=1./255)
val_generator=train_datagen.flow_from_directory(
      '/content/Drive/MyDrive/Colab Notebooks/3IDLDataSet/val', # Fixed the typo in the path. Changed 'drive' to 'Drive'
      target_size=(256, 256),
      class_mode='categorical',
      batch_size=4,

)
# Out:
# Found 1720 images belonging to 3 classes.
# Found 495 images belonging to 3 classes.
# Found 244 images belonging to 3 classes.

# %% [markdown]
# # **Defining my CNN model**

# %%
#Building the model
import numpy as np
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu', input_shape=(256, 256, 3)),
    tf.keras.layers.Conv2D(16, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.4),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(3, activation='softmax')
])

# %% [markdown]
# # **Model fitting**

# %%
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=20,
    validation_data=val_generator,
    validation_steps=len(val_generator),
    verbose=1
)
# Out:
# Epoch 1/15
# 54/54 [==============================] - 976s 18s/step - loss: 0.6579 - accuracy: 0.7930 - val_loss: 0.5947 - val_accuracy: 0.8074
# Epoch 2/15
# 54/54 [==============================] - 360s 7s/step - loss: 0.5867 - accuracy: 0.8041 - val_loss: 0.5023 - val_accuracy: 0.8074
# Epoch 3/15
# 54/54 [==============================] - 359s 7s/step - loss: 0.4765 - accuracy: 0.8477 - val_loss: 0.3978 - val_accuracy: 0.8975
# Epoch 4/15
# 54/54 [==============================] - 361s 7s/step - loss: 0.4099 - accuracy: 0.8802 - val_loss: 0.4396 - val_accuracy: 0.8443
# Epoch 5/15
# 54/54 [==============================] - 352s 7s/step - loss: 0.4454 - accuracy: 0.8692 - val_loss: 0.3195 - val_accuracy: 0.9016
# Epoch 6/15
# 54/54 [==============================] - 367s 7s/step - loss: 0.4105 - accuracy: 0.8756 - val_loss: 0.3823 - val_accuracy: 0.8934
# Epoch 7/15
# ...

# %%
print(model.metrics_names)
print(model.evaluate_generator(test_generator,  verbose=1))
# Out:
# ['loss', 'accuracy']
# <ipython-input-11-9682c00b4455>:2: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   print(model.evaluate_generator(test_generator,  verbose=1))
# 62/62 [==============================] - 247s 4s/step - loss: 0.3194 - accuracy: 0.9111
# [0.3194226026535034, 0.9111111164093018]

# %%
y_true = test_generator.classes
y_test_probabilities = model.predict_generator(test_generator, verbose=1)
y_pred = np.argmax(y_test_probabilities, axis=1)
# Out:
# <ipython-input-12-d67acc91318d>:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   y_test_probabilities = model.predict_generator(test_generator, verbose=1)
# 62/62 [==============================] - 33s 517ms/step

# %%
class_names = train_generator.class_indices
print(class_names)
# Out:
# {'covid': 0, 'normal': 1, 'pneumonia': 2}

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.89      0.92        62
#            1       0.90      1.00      0.95       397
#            2       0.00      0.00      0.00        36
#
#     accuracy                           0.91       495
#    macro avg       0.62      0.63      0.62       495
# weighted avg       0.85      0.91      0.88       495
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_confusion_matrix

# Assuming y_true and y_pred are defined
CM = confusion_matrix(y_true, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=CM, figsize=(5, 5))
plt.show()

# %%
# Save the entire model
model.save('pneumonia.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
